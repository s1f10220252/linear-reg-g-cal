# %%
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import preprocessing
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %% [markdown]
# #### Import my libraries

# %%
my_libs_dir = '../'
if not my_libs_dir in sys.path:
    sys.path.append(my_libs_dir)  # add the path to my_lib directory 

# The following lines are needed to auto-reload my library file
# Without these lines, my library file is read only once and
# modifications of my library file are not reflected.
# %load_ext autoreload
# %autoreload 1
# %aimport my_libs.linear_reg
# import from my library file
from my_libs.linear_reg import step_aic_forward, calc_vifs

# %% [markdown]
# #### Step 1. Collect possible explanatory variables
# 目的変数に影響を与えていそうな要因は、可能な限り網羅的に説明変数に取り入れる。

# %%
csv_in = 'google_calendar_survey.csv'
df_all = pd.read_csv(csv_in)
print(df_all.shape)
print(df_all.info())
display(df_all.head())
# Out:
# (12, 16)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   priority              12 non-null     object
#  1   layout                12 non-null     int64
#  2   font                  12 non-null     int64
#  3   color                 12 non-null     int64
#  4   duplicate             12 non-null     int64
#  5   create                12 non-null     int64
#  6   edit                  12 non-null     int64
#  7   delete                12 non-null     int64
#  8   view_day_week_month   12 non-null     int64
#  9   change_view_settings  12 non-null     int64
#  10  repeat_schedule       12 non-null     int64
#  11  create-manage_tasks   12 non-null     int64
#  12  share                 12 non-null     int64
#  13  satisfaction          12 non-null     int64
#  14  recommend             12 non-null     int64
#  15  continue_using        12 non-null     int64
# dtypes: int64(15), object(1)
# memory usage: 1.6+ KB
# None
#         priority  layout  font  color  duplicate  create  edit  delete  \
# 0      usability       5     4      5          4       5     5       5
# 1     visibility       4     3      5          5       3     4       5
# 2     visibility       5     5      5          4       4     5       5
# 3  functionality       4     3      3          3       3     1       3
# 4      usability       5     5      5          5       5     5       5
#
#    view_day_week_month  change_view_settings  repeat_schedule  \
# 0                    4                     5                5
# 1                    3                     2                5
# 2                    4                     4                5
# 3                    2                     1                2
# 4                    5                     5                5
#
#    create-manage_tasks  share  satisfaction  recommend  continue_using
# 0                    4      5             5          5               5
# 1                    5      4             4          4               2
# 2                    4      4             4          4               5
# 3                    3      4             3          4               5
# 4                    5      5             4          3               2

# %% [markdown]
# ##### Check numerical / category variables if needed
# 数値列・カテゴリー列の様子をみる

# %%
display(df_all.describe())
display(df_all.describe(exclude='number'))
# Out:
#           layout       font      color  duplicate     create       edit  \
# count  12.000000  12.000000  12.000000  12.000000  12.000000  12.000000
# mean    4.333333   3.916667   4.250000   4.166667   3.833333   3.916667
# std     0.651339   0.668558   0.753778   0.717741   1.029857   1.378954
# min     3.000000   3.000000   3.000000   3.000000   2.000000   1.000000
# 25%     4.000000   3.750000   4.000000   4.000000   3.000000   3.000000
# 50%     4.000000   4.000000   4.000000   4.000000   4.000000   4.500000
# 75%     5.000000   4.000000   5.000000   5.000000   5.000000   5.000000
# max     5.000000   5.000000   5.000000   5.000000   5.000000   5.000000
#
#           delete  view_day_week_month  change_view_settings  repeat_schedule  \
# count  12.000000            12.000000             12.000000        12.000000
# mean    4.416667             3.583333              3.333333         4.000000
# std     0.900337             1.164500              1.154701         1.044466
# min     3.000000             2.000000              1.000000         2.000000
# 25%     3.750000             2.750000              3.000000         3.000000
# 50%     5.000000             4.000000              3.000000         4.000000
# 75%     5.000000             4.250000              4.000000         5.000000
# max     5.000000             5.000000              5.000000         5.000000
#
#        create-manage_tasks      share  satisfaction  recommend  continue_using
# count            12.000000  12.000000     12.000000  12.000000       12.000000
# mean              3.916667   3.833333      3.666667   3.250000        3.083333
# std               0.792961   1.114641      0.887625   1.288057        1.781640
# min               3.000000   2.000000      2.000000   1.000000        1.000000
# 25%               3.000000   3.000000      3.750000   2.750000        1.750000
# 50%               4.000000   4.000000      4.000000   4.000000        2.500000
# 75%               4.250000   5.000000      4.000000   4.000000        5.000000
# max               5.000000   5.000000      5.000000   5.000000        5.000000
#           priority
# count           12
# unique           3
# top     visibility
# freq             6

# %%
print(df_all['priority'].value_counts())
# Out:
# priority
# visibility       6
# usability        5
# functionality    1
# Name: count, dtype: int64

# %% [markdown]
# ##### Separate explanatory variables and objective variable
# 説明変数と目的変数を分ける

# %%
X = df_all.loc[:, 'layout':'share']  # explanatory variables
y = df_all['recommend']  # objective variable
print('X:', X.shape)
display(X.head())
print('y:', y.shape)
print(y.head())
# Out:
# X: (12, 12)
#    layout  font  color  duplicate  create  edit  delete  view_day_week_month  \
# 0       5     4      5          4       5     5       5                    4
# 1       4     3      5          5       3     4       5                    3
# 2       5     5      5          4       4     5       5                    4
# 3       4     3      3          3       3     1       3                    2
# 4       5     5      5          5       5     5       5                    5
#
#    change_view_settings  repeat_schedule  create-manage_tasks  share
# 0                     5                5                    4      5
# 1                     2                5                    5      4
# 2                     4                5                    4      4
# 3                     1                2                    3      4
# 4                     5                5                    5      5
# y: (12,)
# 0    5
# 1    4
# 2    4
# 3    4
# 4    3
# Name: recommend, dtype: int64

# %% [markdown]
# #### Step 2. Correlation coefficients between all combination of explanatory variables
# 変数間の相関係数を算出。

# %% [markdown]
# ##### all by all Pearson correlation coefficients;
# 総当たりのPearson相関係数

# %%
corr_all = X.corr(method='pearson')
display(corr_all)
# Out:
#                         layout      font     color  duplicate    create  \
# layout                1.000000  0.695889  0.555492   0.453743  0.632456
# font                  0.695889  1.000000  0.586284   0.221028  0.506137
# color                 0.555492  0.586284  1.000000   0.420084  0.292770
# duplicate             0.453743  0.221028  0.420084   1.000000  0.286972
# create                0.632456  0.506137  0.292770   0.286972  1.000000
# edit                  0.641036  0.682048  0.634091   0.382718  0.757508
# delete                0.516742  0.516019  0.770241   0.304808  0.669974
# view_day_week_month   0.559329  0.651962  0.440162   0.199408  0.164241
# change_view_settings  0.564076  0.745815  0.522233   0.365636  0.509647
# repeat_schedule       0.534522  0.520756  0.692820   0.485071  0.169031
# create-manage_tasks   0.410700  0.328672  0.494305   0.505813 -0.018554
# share                 0.333914  0.101660  0.054100   0.265144  0.052796
#
#                           edit    delete  view_day_week_month  \
# layout                0.641036  0.516742             0.559329
# font                  0.682048  0.516019             0.651962
# color                 0.634091  0.770241             0.440162
# duplicate             0.382718  0.304808             0.199408
# create                0.757508  0.669974             0.164241
# edit                  1.000000  0.835972             0.542543
# delete                0.835972  1.000000             0.267352
# view_day_week_month   0.542543  0.267352             1.000000
# change_view_settings  0.647062  0.378927             0.653544
# repeat_schedule       0.631194  0.386695             0.747435
# create-manage_tasks   0.408767  0.180392             0.746579
# share                 0.049288 -0.196273             0.431900
#
#                       change_view_settings  repeat_schedule  \
# layout                            0.564076         0.534522
# font                              0.745815         0.520756
# color                             0.522233         0.692820
# duplicate                         0.365636         0.485071
# create                            0.509647         0.169031
# edit                              0.647062         0.631194
# delete                            0.378927         0.386695
# view_day_week_month               0.653544         0.747435
# change_view_settings              1.000000         0.678401
# repeat_schedule                   0.678401         1.000000
# create-manage_tasks               0.430237         0.878114
# share                             0.470882         0.546608
#
#                       create-manage_tasks     share
# layout                           0.410700  0.333914
# font                             0.328672  0.101660
# color                            0.494305  0.054100
# duplicate                        0.505813  0.265144
# create                          -0.018554  0.052796
# edit                             0.408767  0.049288
# delete                           0.180392 -0.196273
# view_day_week_month              0.746579  0.431900
# change_view_settings             0.430237  0.470882
# repeat_schedule                  0.878114  0.546608
# create-manage_tasks              1.000000  0.599980
# share                            0.599980  1.000000

# %% [markdown]
# ##### Pickup explanatory variable pairs with large absolute value of correlation coefficient;
# 相関係数の絶対値が大きい説明変数ペアの出力

# %%
th_corr = 0.3
keep = np.triu(np.ones(corr_all.shape), k=1).astype('bool').flatten()
#print(np.ones(corr_all.shape))  # debug
#print(np.triu(np.ones(corr_all.shape), k=1))  # debug
#print(np.triu(np.ones(corr_all.shape), k=1).astype('bool'))  # debug
#print(keep)  # debug
triu = corr_all.stack()[keep]
#print(corr_all.stack())  # debug
triu_sorted = triu[ np.abs(triu).sort_values(ascending=False).index ]
#print(np.abs(triu).sort_values(ascending=False))  # debug
#print(np.abs(triu).sort_values(ascending=False).index)  # debug
print(triu_sorted[ (triu_sorted < -th_corr) | (triu_sorted > th_corr) ])
# Out:
# repeat_schedule       create-manage_tasks     0.878114
# edit                  delete                  0.835972
# color                 delete                  0.770241
# create                edit                    0.757508
# view_day_week_month   repeat_schedule         0.747435
#                       create-manage_tasks     0.746579
# font                  change_view_settings    0.745815
# layout                font                    0.695889
# color                 repeat_schedule         0.692820
# font                  edit                    0.682048
# change_view_settings  repeat_schedule         0.678401
# create                delete                  0.669974
# view_day_week_month   change_view_settings    0.653544
# font                  view_day_week_month     0.651962
# edit                  change_view_settings    0.647062
# layout                edit                    0.641036
# color                 edit                    0.634091
# layout                create                  0.632456
# edit                  repeat_schedule         0.631194
# create-manage_tasks   share                   0.599980
# font                  color                   0.586284
# layout                change_view_settings    0.564076
#                       view_day_week_month     0.559329
#                       color                   0.555492
# repeat_schedule       share                   0.546608
# edit                  view_day_week_month     0.542543
# layout                repeat_schedule         0.534522
# color                 change_view_settings    0.522233
# font                  repeat_schedule         0.520756
# layout                delete                  0.516742
# font                  delete                  0.516019
# create                change_view_settings    0.509647
# font                  create                  0.506137
# duplicate             create-manage_tasks     0.505813
# color                 create-manage_tasks     0.494305
# duplicate             repeat_schedule         0.485071
# change_view_settings  share                   0.470882
# layout                duplicate               0.453743
# color                 view_day_week_month     0.440162
# view_day_week_month   share                   0.431900
# change_view_settings  create-manage_tasks     0.430237
# color                 duplicate               0.420084
# layout                create-manage_tasks     0.410700
# edit                  create-manage_tasks     0.408767
# delete                repeat_schedule         0.386695
# duplicate             edit                    0.382718
# delete                change_view_settings    0.378927
# duplicate             change_view_settings    0.365636
# layout                share                   0.333914
# font                  create-manage_tasks     0.328672
# duplicate             delete                  0.304808
# dtype: float64

# %% [markdown]
# #### Step 3. MLR calculation using all variables
# 全説明変数を用いて、標準化なしで線形重回帰分析

# %%
X_c = sm.add_constant(X)
model = sm.OLS(y, X_c)
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              recommend   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                    nan
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Thu, 27 Jun 2024   Prob (F-statistic):                nan
# Time:                        09:10:29   Log-Likelihood:                 354.28
# No. Observations:                  12   AIC:                            -684.6
# Df Residuals:                       0   BIC:                            -678.7
# Df Model:                          11
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    1.9734        inf          0        nan         nan         nan
# layout                   2.1203        inf          0        nan         nan         nan
# font                    -1.2214        inf         -0        nan         nan         nan
# color                   -0.0646        inf         -0        nan         nan         nan
# duplicate               -1.4095        inf         -0        nan         nan         nan
# create                   0.2731        inf          0        nan         nan         nan
# edit                     0.1000        inf          0        nan         nan         nan
# delete                  -0.6094        inf         -0        nan         nan         nan
# view_day_week_month     -0.1892        inf         -0        nan         nan         nan
# change_view_settings    -0.2253        inf         -0        nan         nan         nan
# repeat_schedule          0.8805        inf          0        nan         nan         nan
# create-manage_tasks      0.8201        inf          0        nan         nan         nan
# share                   -0.2692        inf         -0        nan         nan         nan
# ==============================================================================
# Omnibus:                        4.751   Durbin-Watson:                   0.104
# Prob(Omnibus):                  0.093   Jarque-Bera (JB):                2.506
# Skew:                           1.118   Prob(JB):                        0.286
# Kurtosis:                       3.107   Cond. No.                         179.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The input rank is higher than the number of observations.
# C:\Users\iniad\anaconda3\envs\ds2024\lib\site-packages\scipy\stats\_stats_py.py:1971: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=12
#   k, _ = kurtosistest(a, axis)
# C:\Users\iniad\anaconda3\envs\ds2024\lib\site-packages\statsmodels\regression\linear_model.py:1795: RuntimeWarning: divide by zero encountered in true_divide
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# C:\Users\iniad\anaconda3\envs\ds2024\lib\site-packages\statsmodels\regression\linear_model.py:1795: RuntimeWarning: invalid value encountered in double_scalars
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# C:\Users\iniad\anaconda3\envs\ds2024\lib\site-packages\statsmodels\regression\linear_model.py:1717: RuntimeWarning: divide by zero encountered in double_scalars
#   return np.dot(wresid, wresid) / self.df_resid

# %% [markdown]
# #### Step 4. Check R2 and Adjusted R2 to see whether MLR is appropriate for this data
# 決定係数や自由度調整済み決定係数をみて、そもそも線形モデルの当てはめが妥当かどうかを判断

# %%
print('R2:', results.rsquared)
print('Adj R2:', results.rsquared_adj)
# Out:
# R2: 1.0
# Adj R2: nan

# %%
print(results.params)
# Out:
# const                   1.973416
# layout                  2.120262
# font                   -1.221394
# color                  -0.064575
# duplicate              -1.409466
# create                  0.273128
# edit                    0.099965
# delete                 -0.609396
# view_day_week_month    -0.189240
# change_view_settings   -0.225346
# repeat_schedule         0.880456
# create-manage_tasks     0.820100
# share                  -0.269175
# dtype: float64

# %%
print(results.params.sort_values(key=np.abs, ascending=False))
# Out:
# layout                  2.120262
# const                   1.973416
# duplicate              -1.409466
# font                   -1.221394
# repeat_schedule         0.880456
# create-manage_tasks     0.820100
# delete                 -0.609396
# create                  0.273128
# share                  -0.269175
# change_view_settings   -0.225346
# view_day_week_month    -0.189240
# edit                    0.099965
# color                  -0.064575
# dtype: float64

# %% [markdown]
# #### Step 6. Standardization of variables
# Compare coefficients for explanatory variables
# 全説明変数と目的変数を標準化して線形重回帰分析
# 標準化偏回帰係数を比較

# %%
# NOTE: after scaling, X_scaled and Y_scaled are ndarray, not DataFrame.
X_scaled = preprocessing.scale(X)
y_scaled = preprocessing.scale(y)
# So, make DataFrames corresponding to X_scaled and y_scaled.
dfX_scaled = pd.DataFrame(X_scaled, columns=X.columns)
sery_scaled = pd.Series(y_scaled, name=y.name)

model = sm.OLS(sery_scaled, dfX_scaled)
results = model.fit()
print(results.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:              recommend   R-squared (uncentered):                   1.000
# Model:                            OLS   Adj. R-squared (uncentered):              1.000
# Method:                 Least Squares   F-statistic:                          6.213e+28
# Date:                Thu, 27 Jun 2024   Prob (F-statistic):                    3.13e-15
# Time:                        09:10:29   Log-Likelihood:                          395.15
# No. Observations:                  12   AIC:                                     -768.3
# Df Residuals:                       1   BIC:                                     -763.0
# Df Model:                          11
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# layout                   1.0097   3.41e-15   2.96e+14      0.000       1.010       1.010
# font                    -0.6321   3.06e-15  -2.06e+14      0.000      -0.632      -0.632
# color                    0.1213   2.16e-15   5.61e+13      0.000       0.121       0.121
# duplicate               -0.7539   2.19e-15  -3.45e+14      0.000      -0.754      -0.754
# create                   0.2413   5.36e-15    4.5e+13      0.000       0.241       0.241
# edit                     0.2650   5.38e-15   4.92e+13      0.000       0.265       0.265
# delete                  -0.5927   2.65e-15  -2.24e+14      0.000      -0.593      -0.593
# view_day_week_month     -0.0983   4.01e-15  -2.45e+13      0.000      -0.098      -0.098
# change_view_settings    -0.3027   4.38e-15  -6.91e+13      0.000      -0.303      -0.303
# repeat_schedule          0.6304   6.94e-15   9.08e+13      0.000       0.630       0.630
# create-manage_tasks      0.4183   5.54e-15   7.56e+13      0.000       0.418       0.418
# share                   -0.1574   2.43e-15  -6.47e+13      0.000      -0.157      -0.157
# ==============================================================================
# Omnibus:                        0.482   Durbin-Watson:                   0.698
# Prob(Omnibus):                  0.786   Jarque-Bera (JB):                0.544
# Skew:                           0.260   Prob(JB):                        0.762
# Kurtosis:                       2.096   Cond. No.                     8.18e+16
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The smallest eigenvalue is 1.13e-32. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# C:\Users\iniad\anaconda3\envs\ds2024\lib\site-packages\scipy\stats\_stats_py.py:1971: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=12
#   k, _ = kurtosistest(a, axis)

# %%
print(results.params.sort_values(key=np.abs, ascending=False))
# Out:
# layout                  1.009689
# duplicate              -0.753902
# font                   -0.632052
# repeat_schedule         0.630428
# delete                 -0.592694
# create-manage_tasks     0.418272
# change_view_settings   -0.302685
# edit                    0.264955
# create                  0.241264
# share                  -0.157353
# color                   0.121274
# view_day_week_month    -0.098317
# dtype: float64

# %% [markdown]
# #### Step 7. Feature selection
# 変数選択

# %%
exog = list(dfX_scaled.columns)  # Initial set = all explanatory variables
endog = [sery_scaled.name]  # Objective variables
df_scaled = pd.concat([dfX_scaled, sery_scaled], axis=1)

# %% [markdown]
# #### by forward selection method based on AIC
# 変数増加法による変数選択

# %%
results_aic=step_aic_forward(smf.ols, exog, endog, data=df_scaled)
# Out:
# AIC: 36.055, formula: recommend ~ 1
# AIC: 37.927, formula: recommend ~ create-manage_tasks
# AIC: 33.885, formula: recommend ~ layout
# AIC: 38.025, formula: recommend ~ duplicate
# AIC: 33.907, formula: recommend ~ repeat_schedule
# AIC: 37.155, formula: recommend ~ edit
# AIC: 37.874, formula: recommend ~ change_view_settings
# AIC: 37.844, formula: recommend ~ font
# AIC: 34.988, formula: recommend ~ share
# AIC: 37.510, formula: recommend ~ color
# AIC: 38.013, formula: recommend ~ delete
# AIC: 37.927, formula: recommend ~ create
# AIC: 34.602, formula: recommend ~ view_day_week_month
# AIC: 34.134, formula: recommend ~ layout + create-manage_tasks
# AIC: 33.862, formula: recommend ~ layout + duplicate
# AIC: 34.284, formula: recommend ~ layout + repeat_schedule
# AIC: 35.705, formula: recommend ~ layout + edit
# AIC: 35.016, formula: recommend ~ layout + change_view_settings
# AIC: 33.723, formula: recommend ~ layout + font
# AIC: 34.107, formula: recommend ~ layout + share
# AIC: 35.683, formula: recommend ~ layout + color
# AIC: 34.694, formula: recommend ~ layout + delete
# AIC: 34.134, formula: recommend ~ layout + create
# AIC: 34.885, formula: recommend ~ layout + view_day_week_month
# AIC: 34.127, formula: recommend ~ layout + font + create-manage_tasks
# AIC: 32.234, formula: recommend ~ layout + font + duplicate
# AIC: 32.089, formula: recommend ~ layout + font + repeat_schedule
# AIC: 35.675, formula: recommend ~ layout + font + edit
# AIC: 35.712, formula: recommend ~ layout + font + change_view_settings
# AIC: 34.371, formula: recommend ~ layout + font + share
# AIC: 35.722, formula: recommend ~ layout + font + color
# AIC: 35.066, formula: recommend ~ layout + font + delete
# AIC: 34.127, formula: recommend ~ layout + font + create
# AIC: 31.143, formula: recommend ~ layout + font + view_day_week_month
# AIC: 32.770, formula: recommend ~ layout + font + view_day_week_month + create-manage_tasks
# AIC: 27.754, formula: recommend ~ layout + font + view_day_week_month + duplicate
# AIC: 32.337, formula: recommend ~ layout + font + view_day_week_month + repeat_schedule
# AIC: 33.143, formula: recommend ~ layout + font + view_day_week_month + edit
# AIC: 32.239, formula: recommend ~ layout + font + view_day_week_month + change_view_settings
# AIC: 33.031, formula: recommend ~ layout + font + view_day_week_month + share
# AIC: 33.137, formula: recommend ~ layout + font + view_day_week_month + color
# AIC: 32.793, formula: recommend ~ layout + font + view_day_week_month + delete
# AIC: 32.770, formula: recommend ~ layout + font + view_day_week_month + create
# AIC: 29.225, formula: recommend ~ layout + font + view_day_week_month + duplicate + create-manage_tasks
# AIC: 18.729, formula: recommend ~ layout + font + view_day_week_month + duplicate + repeat_schedule
# AIC: 29.432, formula: recommend ~ layout + font + view_day_week_month + duplicate + edit
# AIC: 29.626, formula: recommend ~ layout + font + view_day_week_month + duplicate + change_view_settings
# AIC: 29.163, formula: recommend ~ layout + font + view_day_week_month + duplicate + share
# AIC: 29.243, formula: recommend ~ layout + font + view_day_week_month + duplicate + color
# AIC: 29.605, formula: recommend ~ layout + font + view_day_week_month + duplicate + delete
# AIC: 29.225, formula: recommend ~ layout + font + view_day_week_month + duplicate + create
# AIC: 20.218, formula: recommend ~ layout + font + view_day_week_month + duplicate + repeat_schedule + create-manage_tasks
# AIC: 20.380, formula: recommend ~ layout + font + view_day_week_month + duplicate + repeat_schedule + edit
# AIC: 15.871, formula: recommend ~ layout + font + view_day_week_month + duplicate + repeat_schedule + change_view_settings
# AIC: 20.634, formula: recommend ~ layout + font + view_day_week_month + duplicate + repeat_schedule + share
# AIC: 17.582, formula: recommend ~ layout + font + view_day_week_month + duplicate + repeat_schedule + color
# AIC: 18.012, formula: recommend ~ layout + font + view_day_week_month + duplicate + repeat_schedule + delete
# AIC: 20.218, formula: recommend ~ layout + font + view_day_week_month + duplicate + repeat_schedule + create
# AIC: 17.788, formula: recommend ~ layout + font + view_day_week_month + duplicate + repeat_schedule + change_view_settings + create-manage_tasks
# AIC: 17.620, formula: recommend ~ layout + font + view_day_week_month + duplicate + repeat_schedule + change_view_settings + edit
# AIC: 17.006, formula: recommend ~ layout + font + view_day_week_month + duplicate + repeat_schedule + change_view_settings + share
# AIC: 8.689, formula: recommend ~ layout + font + view_day_week_month + duplicate + repeat_schedule + change_view_settings + color
# AIC: 11.896, formula: recommend ~ layout + font + view_day_week_month + duplicate + repeat_schedule + change_view_settings + delete
# AIC: 17.788, formula: recommend ~ layout + font + view_day_week_month + duplicate + repeat_schedule + change_view_settings + create
# AIC: 10.568, formula: recommend ~ layout + font + view_day_week_month + duplicate + repeat_schedule + change_view_settings + color + create-manage_tasks
# AIC: 10.653, formula: recommend ~ layout + font + view_day_week_month + duplicate + repeat_schedule + change_view_settings + color + edit
# AIC: 10.275, formula: recommend ~ layout + font + view_day_week_month + duplicate + repeat_schedule + change_view_settings + color + share
# AIC: 9.826, formula: recommend ~ layout + font + view_day_week_month + duplicate + repeat_schedule + change_view_settings + color + delete
# AIC: 10.568, formula: recommend ~ layout + font + view_day_week_month + duplicate + repeat_schedule + change_view_settings + color + create
# The best formula: recommend ~ layout + font + view_day_week_month + duplicate + repeat_schedule + change_view_settings + color
# Minimum AIC: 8.689

# %%
print(results_aic.aic)
print(results_aic.model.exog_names)
print(results_aic.model.endog_names)
# Out:
# 8.689467906020798
# ['Intercept', 'layout', 'font', 'view_day_week_month', 'duplicate', 'repeat_schedule', 'change_view_settings', 'color']
# recommend

# %% [markdown]
# #### Step 8. Check of multicolinearity (VIF checkup)
# マルチコのチェック
#
# ・Iteration of Variable selection (selected_cols) <-> Check VIF
# until all VIFs < 10.
# ・NOTE: standardization of variables does not affect the results

# %%
endogs = results_aic.model.endog_names
exogs = results_aic.model.exog_names.copy()
exogs.remove('Intercept')
print(exogs)  # debug
X_c = sm.add_constant(X[exogs])
vifs = calc_vifs(X_c, y)
display(vifs)
# Out:
# ['layout', 'font', 'view_day_week_month', 'duplicate', 'repeat_schedule', 'change_view_settings', 'color']
#                             VIF
# const                 82.293948
# layout                 2.519010
# font                   4.240478
# view_day_week_month    3.809407
# duplicate              1.711496
# repeat_schedule        5.352489
# change_view_settings   3.238505
# color                  2.800932

# %% [markdown]
# For all explantory variables, VIF < 10, so we can go forward.

# %% [markdown]
# #### Step 9. Estimate the magnitude of the influence of each explanatory variable on the objective variable
# 最終的に得られた標準化偏回帰係数から、各説明変数の目的変数に対する影響の大きさがわかる

# %%
X_final_scaled = dfX_scaled[exogs]
model_final_scaled = sm.OLS(y_scaled, X_final_scaled)
results_final_scaled = model_final_scaled.fit()
print(results_final_scaled.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   0.968
# Model:                            OLS   Adj. R-squared (uncentered):              0.924
# Method:                 Least Squares   F-statistic:                              21.72
# Date:                Thu, 27 Jun 2024   Prob (F-statistic):                     0.00186
# Time:                        09:12:40   Log-Likelihood:                          3.6553
# No. Observations:                  12   AIC:                                      6.689
# Df Residuals:                       5   BIC:                                      10.08
# Df Model:                           7
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# layout                   1.0155      0.127      8.018      0.000       0.690       1.341
# font                    -0.5000      0.164     -3.043      0.029      -0.922      -0.078
# view_day_week_month     -0.0142      0.156     -0.091      0.931      -0.415       0.386
# duplicate               -0.6353      0.104     -6.085      0.002      -0.904      -0.367
# repeat_schedule          1.0636      0.185      5.761      0.002       0.589       1.538
# change_view_settings    -0.3905      0.144     -2.719      0.042      -0.760      -0.021
# color                   -0.3201      0.134     -2.397      0.062      -0.663       0.023
# ==============================================================================
# Omnibus:                        1.053   Durbin-Watson:                   2.041
# Prob(Omnibus):                  0.591   Jarque-Bera (JB):                0.833
# Skew:                          -0.400   Prob(JB):                        0.659
# Kurtosis:                       1.988   Cond. No.                         6.79
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# C:\Users\iniad\anaconda3\envs\ds2024\lib\site-packages\scipy\stats\_stats_py.py:1971: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=12
#   k, _ = kurtosistest(a, axis)

# %%
print(results_final_scaled.params.sort_values(key=np.abs, ascending=False))
# Out:
# repeat_schedule         1.063639
# layout                  1.015512
# duplicate              -0.635277
# font                   -0.500030
# change_view_settings   -0.390471
# color                  -0.320149
# view_day_week_month    -0.014200
# dtype: float64

# %% [markdown]
# The order of strengths of influences on objective variables
# （これが、目的変数に対する各説明変数の影響の大きさ順）

# %% [markdown]
# #### Step 10. Stat. test for MLR equation
# 重回帰式の検定 (求めた重回帰式は目的変数を説明している？)

# %%
print('p-values (F-statistic)', results_final_scaled.f_pvalue)
# Out:
# p-values (F-statistic) 0.0018555099475134147

# %% [markdown]
# #### Step 11. MLR calculation using selected explanatory variables
# 選択された説明変数を用いて、標準化なしで線形重回帰分析

# %%
X_final_c = sm.add_constant(X[exogs])
model_final = sm.OLS(y, X_final_c)
results_final = model_final.fit()
print(results_final.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              recommend   R-squared:                       0.968
# Model:                            OLS   Adj. R-squared:                  0.912
# Method:                 Least Squares   F-statistic:                     17.38
# Date:                Thu, 27 Jun 2024   Prob (F-statistic):            0.00757
# Time:                        09:12:40   Log-Likelihood:                 1.1397
# No. Observations:                  12   AIC:                             13.72
# Df Residuals:                       4   BIC:                             17.60
# Df Model:                           7
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    1.6576      0.998      1.661      0.172      -1.114       4.429
# layout                   2.0082      0.280      7.172      0.002       1.231       2.786
# font                    -0.9634      0.354     -2.722      0.053      -1.946       0.019
# view_day_week_month     -0.0157      0.193     -0.082      0.939      -0.550       0.519
# duplicate               -1.1401      0.209     -5.443      0.006      -1.722      -0.559
# repeat_schedule          1.3117      0.255      5.153      0.007       0.605       2.018
# change_view_settings    -0.4356      0.179     -2.432      0.072      -0.933       0.062
# color                   -0.5471      0.255     -2.144      0.099      -1.255       0.161
# ==============================================================================
# Omnibus:                        1.053   Durbin-Watson:                   2.041
# Prob(Omnibus):                  0.591   Jarque-Bera (JB):                0.833
# Skew:                          -0.400   Prob(JB):                        0.659
# Kurtosis:                       1.988   Cond. No.                         98.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# C:\Users\iniad\anaconda3\envs\ds2024\lib\site-packages\scipy\stats\_stats_py.py:1971: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=12
#   k, _ = kurtosistest(a, axis)

# %% [markdown]
# #### Step 12. Check R2 and Adjusted R2
# 決定係数や自由度調整済み決定係数をみて、線形モデルの当てはまりの良さをチェック

# %%
print('R2:', results_final.rsquared)
print('Adj R2:', results_final.rsquared_adj)
# Out:
# R2: 0.968161787964319
# Adj R2: 0.9124449169018771

# %% [markdown]
# #### Step 13. partial regression coefficients
# 最終的に得られた偏回帰係数から、「各説明変数が1増えたときの目的変数の増分」がわかる。

# %%
print(results_final.params)
# Out:
# const                   1.657566
# layout                  2.008228
# font                   -0.963367
# view_day_week_month    -0.015707
# duplicate              -1.140067
# repeat_schedule         1.311702
# change_view_settings   -0.435566
# color                  -0.547072
# dtype: float64

# %% [markdown]
# Coefficients of MLR;
# Increment of objective variable when corresponding variable is increased by 1
# and other variables are not changed
